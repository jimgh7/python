# %%
# %matplotlib inline

import matplotlib.pyplot as plt

x = [4, 6, 8,  9,  10, 12]
y = [2, 8, 16, 16, 16, 30]

plt.scatter(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.show()

# %%
plt.bar(x, y)
plt.show()

# %%
plt.hist(y)
plt.show()

# %%
plt.boxplot(x)
plt.show()
